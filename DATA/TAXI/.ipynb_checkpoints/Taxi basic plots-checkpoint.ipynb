# %%
import pandas as pd
# %matplotlib inline
import numpy as np
from scipy import stats

# %%
nrows = 1000000
df = pd.read_csv('trip_data_1.csv',nrows=nrows)

# %%
#df.head()
df.columns
# Out:
# Index([u'medallion', u'hack_license', u'vendor_id', u'rate_code',
#        u'store_and_fwd_flag', u'pickup_datetime', u'dropoff_datetime',
#        u'passenger_count', u'trip_time_in_secs', u'trip_distance',
#        u'pickup_longitude', u'pickup_latitude', u'dropoff_longitude',
#        u'dropoff_latitude'],
#       dtype='object')

# %%
df[(df['pickup_latitude'] < 40.0)] = None
df[(df['pickup_latitude'] > 45.0)] = None

df[df['pickup_longitude'] > -70.0] = None
df[df['pickup_longitude'] < -74.5] = None
##df = df[df.notnull()]

# %%
lat = df['pickup_latitude']
long = df['pickup_longitude']
##values = np.vstack([lat,long])
wgood = long.notnull()
lat = lat[wgood]
long = long[wgood]
print lat.isnull().sum(), long.isnull().sum()
# Out:
# 0 0

# %%
xmin = long.min()
xmax = long.max()
ymin = lat.min()
ymax = lat.max()
print xmin, xmax, ymin, ymax
#long
# Out:
# -74.492905 -70.283333 40.033333 43.983334

# %%
im,xedge,yedge = np.histogram2d(long,lat,bins=800, range=[[-74.02,-73.95],[40.7,40.78]])
                                #range=[[-74.05,-73.95],[40.7,40.84]])
                                #range=[[40.6,40.7],[-74.0,-73.5]])
print "im shape", im.shape
#print xedge
im = im.transpose()
# Out:
# im shape (800, 800)

# %%
plt.figure(figsize=(10,10))
plt.imshow(np.sqrt(im), origin = 'low', aspect=1.7, cmap='hot')
plt.xticks([])
plt.yticks([])
##plt.set_cmap("Green")
#im

##im
plt.savefig('test.pdf', bbox_inches='tight')

# %%
X, Y = np.mgrid[xmin:xmax:100j, ymin:ymax:100j]
positions = np.vstack([X.ravel(), Y.ravel()])
kernel = stats.gaussian_kde(values)
Z = np.reshape(kernel(positions).T, X.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-bd86ab8a6c99> in <module>()
#       5 X, Y = np.mgrid[xmin:xmax:100j, ymin:ymax:100j]
#       6 positions = np.vstack([X.ravel(), Y.ravel()])
# ----> 7 kernel = stats.gaussian_kde(values)
#       8 Z = np.reshape(kernel(positions).T, X.shape)
#
# /Users/jgabor/anaconda/lib/python2.7/site-packages/scipy/stats/kde.pyc in __init__(self, dataset, bw_method)
#     169
#     170         self.d, self.n = self.dataset.shape
# --> 171         self.set_bandwidth(bw_method=bw_method)
#     172
#     173     def evaluate(self, points):
#
# /Users/jgabor/anaconda/lib/python2.7/site-packages/scipy/stats/kde.pyc in set_bandwidth(self, bw_method)
#     486             raise ValueError(msg)
#     487
# --> 488         self._compute_covariance()
#     489
#     490     def _compute_covariance(self):
#
# ...

# %%
plt.imshow(np.log10(Z))

# %%
positions
# Out:
# array([[  0.        ,   0.        ,   0.        , ...,  40.889069  ,
#          40.889069  ,  40.889069  ],
#        [-74.016403  , -73.26876257, -72.52112213, ...,  -1.49528087,
#          -0.74764043,   0.        ]])
