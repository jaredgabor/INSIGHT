# %%
import pandas as pd
# %matplotlib inline
import numpy as np
from scipy import stats

# %%
nrows = 1000000
df = pd.read_csv('trip_data_1.csv',nrows=nrows)

# %%
#df.head()
df.columns
# Out:
# Index([u'medallion', u'hack_license', u'vendor_id', u'rate_code',
#        u'store_and_fwd_flag', u'pickup_datetime', u'dropoff_datetime',
#        u'passenger_count', u'trip_time_in_secs', u'trip_distance',
#        u'pickup_longitude', u'pickup_latitude', u'dropoff_longitude',
#        u'dropoff_latitude'],
#       dtype='object')

# %%
df[(df['pickup_latitude'] < 40.0)] = None
df[(df['pickup_latitude'] > 45.0)] = None

df[df['pickup_longitude'] > -70.0] = None
df[df['pickup_longitude'] < -74.5] = None
##df = df[df.notnull()]

# %%
df[(df['medallion'] == df['medallion'][15000])]
# Out:
#                                medallion                      hack_license  \
# 5867    D99FFC82367536B36EAB9D94C89FDB02  6D6F36E52081FCF5A27706A614EBE53E
# 9624    D99FFC82367536B36EAB9D94C89FDB02  6D6F36E52081FCF5A27706A614EBE53E
# 15000   D99FFC82367536B36EAB9D94C89FDB02  6D6F36E52081FCF5A27706A614EBE53E
# 24692   D99FFC82367536B36EAB9D94C89FDB02  6D6F36E52081FCF5A27706A614EBE53E
# 31976   D99FFC82367536B36EAB9D94C89FDB02  6D6F36E52081FCF5A27706A614EBE53E
# 42858   D99FFC82367536B36EAB9D94C89FDB02  6D6F36E52081FCF5A27706A614EBE53E
# 43989   D99FFC82367536B36EAB9D94C89FDB02  6D6F36E52081FCF5A27706A614EBE53E
# 50129   D99FFC82367536B36EAB9D94C89FDB02  6D6F36E52081FCF5A27706A614EBE53E
# 54629   D99FFC82367536B36EAB9D94C89FDB02  6D6F36E52081FCF5A27706A614EBE53E
# 56334   D99FFC82367536B36EAB9D94C89FDB02  6D6F36E52081FCF5A27706A614EBE53E
# 57776   D99FFC82367536B36EAB9D94C89FDB02  6D6F36E52081FCF5A27706A614EBE53E
# ...
